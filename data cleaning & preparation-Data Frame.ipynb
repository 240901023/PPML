# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")

df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))

df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))

df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())

df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe with NaN
#          one       two     three
# a  1.576249 -0.624265  0.308576
# b       NaN       NaN       NaN
# c -0.539769  0.108660 -0.182905
# d  0.588362 -0.681552  0.284872
# e       NaN       NaN       NaN
# f  0.231825  0.124672  0.970394
#
#
# Dropped DataFrame
#          one       two     three
# a  1.576249 -0.624265  0.308576
# c -0.539769  0.108660 -0.182905
# d  0.588362 -0.681552  0.284872
# f  0.231825  0.124672  0.970394
#
#
# Original Dataframe:
#          one       two     three
# a -0.831488 -0.334943 -0.252236
# b       NaN       NaN       NaN
# c -0.549949 -0.805092  1.872576
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.831488 -0.334943 -0.252236
# b  0.000000  0.000000  0.000000
# c -0.549949 -0.805092  1.872576
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5
# Original Dataframe:
#          one       two     three
# a  0.119359  0.332294  0.246314
# b       NaN       NaN       NaN
# c  0.902302 -0.313313 -1.660155
# d  2.157072 -0.636261 -0.579903
# e       NaN       NaN       NaN
# f  0.012450  1.877687  1.163648
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool
# Original Dataframe:
#          one       two     three
# a  0.680662  0.309845  0.951211
# b       NaN       NaN       NaN
# c -0.125111 -0.033999 -0.573964
# d -1.521015 -1.043459 -0.214113
# e       NaN       NaN       NaN
# f -0.854275  0.032259 -0.072853
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.680662  0.309845  0.951211
# b -0.125111 -0.033999 -0.573964
# c -0.125111 -0.033999 -0.573964
# d -1.521015 -1.043459 -0.214113
# e -0.854275  0.032259 -0.072853
# f -0.854275  0.032259 -0.072853
# /tmp/ipykernel_302/1728042192.py:37: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
